# %% [markdown]
# # Motion Planning for Manipulators
#
# Author: Daoming Chen
#
# <figure style="text-align: center; margin: 20px 0;">
#     <img src="https://daoming-chen.github.io/MP_lecture_assets/cover.png"
#          width="100%"
#          style="display: block; margin: 0 auto;">
#     <figcaption style="font-size: 0; height: 0;"></figcaption>
# </figure>
#
# This website contains the full text of the [Motion Planning for Manipulators](https://daoming-chen.github.io/Motion-Planning-for-Manipulators) by Daoming Chen; the content is available on [GitHub](https://github.com/Daoming-Chen/Motion-Planning-for-Manipulators) in the form of Jupyter notebooks.
#
# The text is released under the [CC BY-SA](https://creativecommons.org/licenses/by-sa/4.0/legalcode) license, and code is released under the [MIT](https://opensource.org/license/MIT) license.
#
# ## Table of Contents
#
# * [Lec 0. Intro to Motion Planning for Manipulators](https://daoming-chen.github.io/Motion-Planning-for-Manipulators/notebooks/00_intro.html)
